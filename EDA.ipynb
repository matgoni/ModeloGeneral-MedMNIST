# %% [markdown]
# # EDA para MedMNIST2D

# %%
from scripts.EDA import (listar_datasets_medmnist, ejecutar_coleccion_medmnist)

# %%
from scripts.EDA import plot_imbalance_bar, plot_entropy_gini_scatter

# %%
# 1) Datasets (todos 2D)
datasets = listar_datasets_medmnist(include_3d=False)

# 2) Ejecutar análisis
df_resumen, obj_detallado = ejecutar_coleccion_medmnist(
    datasets=datasets,
    splits=("train",),
    download=True
)

df_resumen
# Out:
# 100%|██████████| 35.5M/35.5M [00:21<00:00, 1.64MB/s]
# 100%|██████████| 560k/560k [00:00<00:00, 598kB/s]
# 100%|██████████| 82.8M/82.8M [00:27<00:00, 3.03MB/s]
# 100%|██████████| 19.7M/19.7M [00:16<00:00, 1.20MB/s]
# 100%|██████████| 54.9M/54.9M [00:17<00:00, 3.23MB/s]
# 100%|██████████| 38.2M/38.2M [00:10<00:00, 3.57MB/s]
# 100%|██████████| 15.5M/15.5M [00:08<00:00, 1.92MB/s]
# 100%|██████████| 16.5M/16.5M [00:05<00:00, 3.16MB/s]
# 100%|██████████| 206M/206M [22:59<00:00, 149kB/s]
# 100%|██████████| 4.17M/4.17M [00:08<00:00, 478kB/s]
# 100%|██████████| 3.29M/3.29M [00:02<00:00, 1.62MB/s]
# 100%|██████████| 125M/125M [00:54<00:00, 2.29MB/s]
#            dataset  split                       task  multilabel  n_samples  \
# 0       bloodmnist  train                multi-class       False      11959
# 1      breastmnist  train               binary-class       False        546
# 2       chestmnist  train  multi-label, binary-class        True      78468
# ...

# %%
df_resumen['dataset'].tolist()
# Out:
# ['bloodmnist',
#  'breastmnist',
#  'chestmnist',
#  'dermamnist',
#  'octmnist',
#  'organamnist',
#  'organcmnist',
#  'organsmnist',
#  'pathmnist',
#  'pneumoniamnist',
#  'retinamnist',
#  'tissuemnist']

# %%
plot_imbalance_bar(df_resumen, split="train")
# Out:
# /Users/matgoni/Projects/ModeloGeneral-MedMNIST/scripts/EDA.py:172: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plot_entropy_gini_scatter(df_resumen, split="train")

# %% [markdown]
# ## T-SNE

# %%
from scripts.TSNE import plot_tsne_clusters #Específico

# %%
plot_tsne_clusters(dataset_name='breastmnist')
# Out:
# Aplicando t-SNE a 546 muestras de breastmnist...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plot_tsne_clusters(dataset_name='breastmnist')
#
# File ~/Projects/ModeloGeneral-MedMNIST/scripts/TSNE.py:39, in plot_tsne_clusters(dataset_name, split, n_samples, random_state, perplexity, download)
#      36 X = imgs.reshape(imgs.shape[0], -1).astype('float32') / 255.0
#      38 print(f"Aplicando t-SNE a {n_samples} muestras de {dataset_name}...")
# ---> 39 tsne = TSNE(
#      40     n_components=2,
#      41     perplexity=perplexity,
#      42     n_iter=2000,
#      43     random_state=random_state,
#      44     verbose=1
#      45 )
#      46 X_embedded = tsne.fit_transform(X)
#      48 # Mapeo de etiquetas
#
# TypeError: TSNE.__init__() got an unexpected keyword argument 'n_iter'

# %% [markdown]
# ## TSNE entre datasets

# %%
from scripts.TSNE2 import TSNEVisualizer

# %%
viz = TSNEVisualizer(
    dataset_names=['bloodmnist',
                    'breastmnist',
                    'chestmnist',
                    'dermamnist',
                    'octmnist',
                    'organamnist',
                    'organcmnist',
                    'organsmnist',
                    'pathmnist',
                    'pneumoniamnist',
                    'retinamnist',
                    'tissuemnist'], 
    samples_per_dataset=1500, color_mode="original")
viz.plot(color_by="dataset")
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 16626 samples in 0.005s...
# [t-SNE] Computed neighbors for 16626 samples in 3.601s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 16626
# [t-SNE] Computed conditional probabilities for sample 2000 / 16626
# [t-SNE] Computed conditional probabilities for sample 3000 / 16626
# [t-SNE] Computed conditional probabilities for sample 4000 / 16626
# [t-SNE] Computed conditional probabilities for sample 5000 / 16626
# [t-SNE] Computed conditional probabilities for sample 6000 / 16626
# [t-SNE] Computed conditional probabilities for sample 7000 / 16626
# [t-SNE] Computed conditional probabilities for sample 8000 / 16626
# [t-SNE] Computed conditional probabilities for sample 9000 / 16626
# [t-SNE] Computed conditional probabilities for sample 10000 / 16626
# [t-SNE] Computed conditional probabilities for sample 11000 / 16626
# [t-SNE] Computed conditional probabilities for sample 12000 / 16626
# ...

# %%
viz = TSNEVisualizer(
    dataset_names=['bloodmnist',
                    'breastmnist',
                    'chestmnist',
                    'dermamnist',
                    'octmnist',
                    'organamnist',
                    'organcmnist',
                    'organsmnist',
                    'pathmnist',
                    'pneumoniamnist',
                    'retinamnist',
                    'tissuemnist'], 
    samples_per_dataset=1500, color_mode="grayscale")
viz.plot(color_by="dataset")
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 16626 samples in 0.002s...
# [t-SNE] Computed neighbors for 16626 samples in 1.035s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 16626
# [t-SNE] Computed conditional probabilities for sample 2000 / 16626
# [t-SNE] Computed conditional probabilities for sample 3000 / 16626
# [t-SNE] Computed conditional probabilities for sample 4000 / 16626
# [t-SNE] Computed conditional probabilities for sample 5000 / 16626
# [t-SNE] Computed conditional probabilities for sample 6000 / 16626
# [t-SNE] Computed conditional probabilities for sample 7000 / 16626
# [t-SNE] Computed conditional probabilities for sample 8000 / 16626
# [t-SNE] Computed conditional probabilities for sample 9000 / 16626
# [t-SNE] Computed conditional probabilities for sample 10000 / 16626
# [t-SNE] Computed conditional probabilities for sample 11000 / 16626
# [t-SNE] Computed conditional probabilities for sample 12000 / 16626
# ...

# %%
viz = TSNEVisualizer(
    dataset_names=['bloodmnist',
                    'breastmnist',
                    'dermamnist',
                    'organamnist',
                    'organcmnist',
                    'organsmnist',
                    'pathmnist',
                    'pneumoniamnist',
                    'tissuemnist'], 
    samples_per_dataset=1500)
viz.plot(color_by="dataset")

# %% [markdown]
# ## Coeficiente de silueta

# %%
from scripts.silhouette import SilhouetteAnalyzer

# %%
analyzer = SilhouetteAnalyzer(['bloodmnist','breastmnist', 'chestmnist', 'dermamnist', 'octmnist', 'organamnist', 'organcmnist', 'organsmnist', 'pathmnist', 'pneumoniamnist','retinamnist','tissuemnist'], samples_per_dataset=1500)
score_classes = analyzer.mean_score(label_level="class")

# %%
print("Silhouette por clase:", score_classes)

# %%
score_dataset = analyzer.mean_score(label_level="dataset")
print("Silhouette por dataset:", score_dataset)

# %% [markdown]
# ## Histogramas

# %%
from scripts.EDA import ejecutar_coleccion_medmnist, plot_class_histograms
df_resumen, obj_detallado = ejecutar_coleccion_medmnist(splits=("train",))
plot_class_histograms(obj_detallado, split="train")

# %% [markdown]
# ## Correlaciones

# %%
from scripts.EDA import plot_rgb_channel_correlations # RGB
plot_rgb_channel_correlations(split="train", sample_size=1000)

# %%
from scripts.CORR import correlation_between_datasets, plot_dataset_correlation_heatmap

df_corr = correlation_between_datasets(split="train", sample_size=1000)

df_corr

# %%
plot_dataset_correlation_heatmap(df_corr)
