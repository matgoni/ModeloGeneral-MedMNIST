# %% [markdown]
# # EDA para MedMNIST2D

# %%
from EDA import (listar_datasets_medmnist, ejecutar_coleccion_medmnist)

# %%
from EDA import plot_imbalance_bar, plot_entropy_gini_scatter

# %%
# 1) Datasets (todos 2D)
datasets = listar_datasets_medmnist(include_3d=False)

# 2) Ejecutar análisis
df_resumen, obj_detallado = ejecutar_coleccion_medmnist(
    datasets=datasets,
    splits=("train",),
    download=True
)

df_resumen
# Out:
#            dataset  split                       task  multilabel  n_samples  \
# 0       bloodmnist  train                multi-class       False      11959
# 1      breastmnist  train               binary-class       False        546
# 2       chestmnist  train  multi-label, binary-class        True      78468
# 3       dermamnist  train                multi-class       False       7007
# 4         octmnist  train                multi-class       False      97477
# 5      organamnist  train                multi-class       False      34561
# 6      organcmnist  train                multi-class       False      12975
# 7      organsmnist  train                multi-class       False      13932
# 8        pathmnist  train                multi-class       False      89996
# 9   pneumoniamnist  train               binary-class       False       4708
# 10     retinamnist  train         ordinal-regression       False       1080
# ...

# %%
df_resumen['dataset'].tolist()
# Out:
# ['bloodmnist',
#  'breastmnist',
#  'chestmnist',
#  'dermamnist',
#  'octmnist',
#  'organamnist',
#  'organcmnist',
#  'organsmnist',
#  'pathmnist',
#  'pneumoniamnist',
#  'retinamnist',
#  'tissuemnist']

# %%
plot_imbalance_bar(df_resumen, split="train")
# Out:
# /home/matgoni/MICAI25/EDA.py:172: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plot_entropy_gini_scatter(df_resumen, split="train")

# %% [markdown]
# ## T-SNE

# %%
from TSNE import plot_tsne_clusters #Específico

# %%
plot_tsne_clusters(dataset_name='breastmnist')
# Out:
# Aplicando t-SNE a 546 muestras de breastmnist...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_tsne_clusters(dataset_name='breastmnist')
#
# File ~/MICAI25/TSNE.py:39, in plot_tsne_clusters(dataset_name, split, n_samples, random_state, perplexity, download)
#      36 X = imgs.reshape(imgs.shape[0], -1).astype('float32') / 255.0
#      38 print(f"Aplicando t-SNE a {n_samples} muestras de {dataset_name}...")
# ---> 39 tsne = TSNE(
#      40     n_components=2,
#      41     perplexity=perplexity,
#      42     n_iter=2000,
#      43     random_state=random_state,
#      44     verbose=1
#      45 )
#      46 X_embedded = tsne.fit_transform(X)
#      48 # Mapeo de etiquetas
#
# TypeError: TSNE.__init__() got an unexpected keyword argument 'n_iter'

# %% [markdown]
# ## TSNE entre datasets

# %%
from TSNE2 import TSNEVisualizer

# %%
viz = TSNEVisualizer(
    dataset_names=['bloodmnist',
                    'breastmnist',
                    'chestmnist',
                    'dermamnist',
                    'octmnist',
                    'organamnist',
                    'organcmnist',
                    'organsmnist',
                    'pathmnist',
                    'pneumoniamnist',
                    'retinamnist',
                    'tissuemnist'], 
    samples_per_dataset=1500)
viz.plot(color_by="dataset")
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 16626 samples in 0.004s...
# [t-SNE] Computed neighbors for 16626 samples in 10.493s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 16626
# [t-SNE] Computed conditional probabilities for sample 2000 / 16626
# [t-SNE] Computed conditional probabilities for sample 3000 / 16626
# [t-SNE] Computed conditional probabilities for sample 4000 / 16626
# [t-SNE] Computed conditional probabilities for sample 5000 / 16626
# [t-SNE] Computed conditional probabilities for sample 6000 / 16626
# [t-SNE] Computed conditional probabilities for sample 7000 / 16626
# [t-SNE] Computed conditional probabilities for sample 8000 / 16626
# [t-SNE] Computed conditional probabilities for sample 9000 / 16626
# [t-SNE] Computed conditional probabilities for sample 10000 / 16626
# [t-SNE] Computed conditional probabilities for sample 11000 / 16626
# [t-SNE] Computed conditional probabilities for sample 12000 / 16626
# ...

# %%
viz = TSNEVisualizer(
    dataset_names=['bloodmnist',
                    'breastmnist',
                    'dermamnist',
                    'organamnist',
                    'organcmnist',
                    'organsmnist',
                    'pathmnist',
                    'pneumoniamnist',
                    'tissuemnist'], 
    samples_per_dataset=1500)
viz.plot(color_by="dataset")
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 12546 samples in 0.004s...
# [t-SNE] Computed neighbors for 12546 samples in 12.117s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 12546
# [t-SNE] Computed conditional probabilities for sample 2000 / 12546
# [t-SNE] Computed conditional probabilities for sample 3000 / 12546
# [t-SNE] Computed conditional probabilities for sample 4000 / 12546
# [t-SNE] Computed conditional probabilities for sample 5000 / 12546
# [t-SNE] Computed conditional probabilities for sample 6000 / 12546
# [t-SNE] Computed conditional probabilities for sample 7000 / 12546
# [t-SNE] Computed conditional probabilities for sample 8000 / 12546
# [t-SNE] Computed conditional probabilities for sample 9000 / 12546
# [t-SNE] Computed conditional probabilities for sample 10000 / 12546
# [t-SNE] Computed conditional probabilities for sample 11000 / 12546
# [t-SNE] Computed conditional probabilities for sample 12000 / 12546
# ...

# %% [markdown]
# ## Histogramas

# %%
from EDA import ejecutar_coleccion_medmnist, plot_class_histograms
df_resumen, obj_detallado = ejecutar_coleccion_medmnist(splits=("train",))
plot_class_histograms(obj_detallado, split="train")
# Out:
# e:\ModeloGeneral-MedMNIST\EDA.py:315: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=np.arange(len(counts)), y=counts, ax=ax, palette="viridis")
# e:\ModeloGeneral-MedMNIST\EDA.py:315: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=np.arange(len(counts)), y=counts, ax=ax, palette="viridis")
# e:\ModeloGeneral-MedMNIST\EDA.py:315: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=np.arange(len(counts)), y=counts, ax=ax, palette="viridis")
# e:\ModeloGeneral-MedMNIST\EDA.py:315: FutureWarning:
#
# ...

# %% [markdown]
# ## Correlaciones

# %%
from EDA import plot_rgb_channel_correlations # RGB
plot_rgb_channel_correlations(split="train", sample_size=1000)

# %%
from CORR import correlation_between_datasets, plot_dataset_correlation_heatmap

df_corr = correlation_between_datasets(split="train", sample_size=1000)

df_corr
# Out:
#                 bloodmnist  breastmnist  chestmnist  dermamnist  octmnist  \
# bloodmnist        1.000000     0.097275   -0.156165    0.741556 -0.175187
# breastmnist       0.097275     1.000000   -0.575281    0.048909  0.551143
# chestmnist       -0.156165    -0.575281    1.000000   -0.090513 -0.364297
# dermamnist        0.741556     0.048909   -0.090513    1.000000 -0.160669
# octmnist         -0.175187     0.551143   -0.364297   -0.160669  1.000000
# organamnist      -0.091633     0.177414    0.328924   -0.051745 -0.212335
# organcmnist      -0.090578     0.372098    0.110015   -0.087769  0.042435
# organsmnist      -0.476830     0.196352    0.220726   -0.338093  0.207714
# pathmnist         0.315294    -0.006553    0.006928    0.582854 -0.007847
# pneumoniamnist   -0.319863    -0.405825    0.751388   -0.153584 -0.305606
# retinamnist      -0.394420    -0.085880    0.337999    0.075575  0.051766
# tissuemnist      -0.739514    -0.008965    0.125116   -0.486050  0.293658
#
# ...

# %%
plot_dataset_correlation_heatmap(df_corr)
